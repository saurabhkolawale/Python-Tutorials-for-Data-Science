# %% [markdown]
# #     File Reading Operation

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV

# %%
#Reading a CSV file

df1 = pd.read_csv(r'C:\Users\sai\Downloads\ML-Krish Naik Class\Pandas\code_pandas1\examples\ex1.csv')

df1.head()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
#Reading CSV without a Header

df2 = pd.read_csv(r'C:\Users\sai\Downloads\ML-Krish Naik Class\Pandas\code_pandas1\examples\ex1.csv', header =None)

df2.head()
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
df3 = pd.read_csv(r'C:\Users\sai\Downloads\ML-Krish Naik Class\Pandas\code_pandas1\examples\csv_mindex.csv',
                 index_col = ['key1','key2'])

df3
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
df4 = pd.read_csv(r'C:\Users\sai\Downloads\ML-Krish Naik Class\Pandas\code_pandas1\examples\ex5.csv',
                 na_values= ['Null'])

df4
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %% [markdown]
# ## EXCEL

# %%
df5 = pd.read_excel(r'C:\Users\sai\Downloads\ML-Krish Naik Class\Pandas\code_pandas1\examples\Transaction.xlsx', 
                    sheet_name='Last Transactions')
df5

#While imporing excel file, we need to specify the sheet name. Other wise pandas will take the first sheet by default
# Out:
#          Date  Credited  Debited   Medium  Amount
# 0  2019-11-01      1000      0.0  Mr. ABC    1000
# 1  2019-11-02         0    500.0      POS     500
# 2  2019-11-03         0    200.0     IMPS     300
# 3  2019-11-04     15000      NaN  Mr. XYZ   15300
# 4  2019-11-05         0  10000.0     IMPS    5300
# 5  2019-11-06         0   3000.0      POS    2300
# 6  2019-11-07     20000      0.0  Mr. XYZ   22300
# 7  2019-11-08     50000      0.0  Mr. ABC   72300
# 8  2019-11-09         0   2300.0      POS   70000
# 9  2019-11-10         0  10000.0     IMPS   60000
# 10 2019-11-11         0  55000.0      POS    5000

# %% [markdown]
# ## HTML

# %%
url = "http://www.basketball-reference.com/leagues/NBA_2015_totals.html"

BasBall_data = pd.read_html(url)         # Read data from the specified url

BasBall_data[0].ix[:, 0:20].head(5)   # Check 5 rows (10 columns only)
# Out:
# C:\Users\sai\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA   FG%   3P  3PA  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  .459   18   60
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  .407   10   25
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  .544    0    2
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  .432    0    0
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  .424  118  333
#
#     3P%   2P  2PA   2P%  eFG%   FT  FTA
# 0  .300  134  271  .494  .486   76   97
# 1  .400   25   61  .410  .465   14   23
# 2  .000  217  397  .547  .544  103  205
# 3   NaN   19   44  .432  .432   22   38
# ...

# %% [markdown]
# ## Basic Dataset Operations

# %%
#The file is csv file with TAB as a separator, hence we need to set another parameter sep = '\t' while importing the file

titanic_data = pd.read_csv(r'https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv',
                          sep = '\t')

titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#To fetch columns from the dataset

titanic_data[['Name','Age']].head()
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
#To find the data type of each column in the dataset

titanic_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## JSON

# %%
#Initially copy your JSON API response in a variable between ''' JSON API RESPONSE  '''



obj = '''
{
  "data": [{
    "type": "articles",
    "id": "1",
    "attributes": {
      "title": "JSON:API paints my bikeshed!",
      "body": "The shortest article. Ever.",
      "created": "2015-05-22T14:56:29.000Z",
      "updated": "2015-05-22T14:56:28.000Z"
    },
    "relationships": {
      "author": {
        "data": {"id": "42", "type": "people"}
      }
    }
  }],
  "included": [
    {
      "type": "people",
      "id": "42",
      "attributes": {
        "name": "John",
        "age": 80,
        "gender": "male"
      }
    }
  ]
}
'''

# %%
#Load that variable in JSON and save in other variable

import json

df7 = json.loads(obj)
df7
# Out:
# {'data': [{'type': 'articles',
#    'id': '1',
#    'attributes': {'title': 'JSON:API paints my bikeshed!',
#     'body': 'The shortest article. Ever.',
#     'created': '2015-05-22T14:56:29.000Z',
#     'updated': '2015-05-22T14:56:28.000Z'},
#    'relationships': {'author': {'data': {'id': '42', 'type': 'people'}}}}],
#  'included': [{'type': 'people',
#    'id': '42',
#    'attributes': {'name': 'John', 'age': 80, 'gender': 'male'}}]}

# %%
#Dump the result obtained in the JSON and get your required Data

json.dumps(df7)
# Out:
# '{"data": [{"type": "articles", "id": "1", "attributes": {"title": "JSON:API paints my bikeshed!", "body": "The shortest article. Ever.", "created": "2015-05-22T14:56:29.000Z", "updated": "2015-05-22T14:56:28.000Z"}, "relationships": {"author": {"data": {"id": "42", "type": "people"}}}}], "included": [{"type": "people", "id": "42", "attributes": {"name": "John", "age": 80, "gender": "male"}}]}'

# %% [markdown]
# ## Web Api

# %%
#First we need to hit the API and get the service response

url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

import requests

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
#Convert the obtained response in JSON format to get the data

data = response.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29667',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29667/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29667/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29667/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29667',
#   'id': 523932765,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQxODE3OTkz',
#   'number': 29667,
#   'title': 'TYP: core.computations.scope',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
# ...

# %%
df8  = pd.DataFrame(data)
df8.head()
# Out:
#   assignee assignees author_association  \
# 0     None        []             MEMBER
# 1     None        []             MEMBER
# 2     None        []             MEMBER
# 3     None        []             MEMBER
# 4     None        []        CONTRIBUTOR
#
#                                                 body closed_at  comments  \
# 0  mypy does _not_ play nicely with DeepChainMap....      None         0
# 1  - [ ] closes #xxxx\r\n- [ ] tests added / pass...      None         0
# 2  Some annotations.  I'm finding that annotation...      None         1
# 3  May be I'm missing something, but is there a r...      None         2
# 4  The function was returning True in case shown ...      None         1
#
#                                         comments_url            created_at  \
# 0  https://api.github.com/repos/pandas-dev/pandas...  2019-11-17T04:15:11Z
# 1  https://api.github.com/repos/pandas-dev/pandas...  2019-11-17T03:46:26Z
# ...
